# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# #Creation of Pandas Series

# %% [markdown]
# A Pandas series can be created using list, tuple, dictionary and numpy array.

# %%
population_dict = {
    'California':38956785,
    'Texas':26441568,
    'New York':19555647,
    'Florida':12364569,
    'Illinois':12882135
}

population_dict
# Out:
# {'California': 38956785,
#  'Texas': 26441568,
#  'New York': 19555647,
#  'Florida': 12364569,
#  'Illinois': 12882135}

# %%
type(population_dict)
# Out:
# dict

# %%
population = pd.Series(population_dict)
population
# Out:
# California    38956785
# Texas         26441568
# New York      19555647
# Florida       12364569
# Illinois      12882135
# dtype: int64

# %%
population.index
# Out:
# Index(['California', 'Texas', 'New York', 'Florida', 'Illinois'], dtype='object')

# %%
population.California
# Out:
# 38956785

# %%
population[0]
# Out:
# <ipython-input-7-35923939627a>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   population[0]
# 38956785

# %%
population
# Out:
# California    38956785
# Texas         26441568
# New York      19555647
# Florida       12364569
# Illinois      12882135
# dtype: int64

# %%
population['California':'New York']
# Out:
# California    38956785
# Texas         26441568
# New York      19555647
# dtype: int64

# %%
len_list=len([2,4,6,8])

import numpy as np
print(np.arange(len_list))
# Out:
# [0 1 2 3]

# %%
pd.Series([2,4,6,8])  # creating series with list


# default index is created in pandas using numpy.arange(len(list))
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# dtype: int64

# %%
pd.Series((1,2,3,4))       # creating series with tuple
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
x=np.array([9,10,11,12,13])
pd.Series(x)                   # creating series with numpy array
# Out:
# 0     9
# 1    10
# 2    11
# 3    12
# 4    13
# dtype: int64

# %%
#create a series using numpy array in below cell take any random numbers

# %%
#answer here

# %%
pd.Series( [2,4,6] , index=[100,200,300] )               # setting up the customized index to array
# Out:
# 100    2
# 200    4
# 300    6
# dtype: int64

# %%
pd.Series( 5 )                          # creating array for a scaler value
# Out:
# 0    5
# dtype: int64

# %%
pd.Series( 5 , index=[100,200,300] )


# it gives preferances to the index
# Out:
# 100    5
# 200    5
# 300    5
# dtype: int64

# %%
pd.Series( {2:'a' ,  1:'b', 3:'c'} )
# Out:
# 2    a
# 1    b
# 3    c
# dtype: object

# %%
pd.Series( {2:'a' ,  1:'b', 3:'c'}, index=[3,2,4,5] )
# if key of the dictonary doesn't match with index then it will fill the series with NaN values
# Out:
# 3      c
# 2      a
# 4    NaN
# 5    NaN
# dtype: object

# %% [markdown]
# #Type and Shape of the series

# %% [markdown]
# To check the type of the Series use type() and to check the shape of the series use .shape.

# %%
population
# Out:
# California    38956785
# Texas         26441568
# New York      19555647
# Florida       12364569
# Illinois      12882135
# dtype: int64

# %%
type(population)
# Out:
# pandas.core.series.Series

# %%
population.shape # Series
# Out:
# (5,)

# %% [markdown]
# # Data Frame

# %% [markdown]
# Creating Pandas DataFrame A pandas DataFrame can be created using pandas Series, dictionary, list, tuple and numpy array.
#
# To create pandas DataFrame use pd.DataFrame()

# %%
population_dict = {
    'California':38956785,
    'Texas':26441568,
    'New York':19555647,
    'Florida':12364569,
    'Illinois':12882135
}

population=pd.Series(population_dict)
df = pd.DataFrame(population)
df
# Out:
#                    0
# California  38956785
# Texas       26441568
# New York    19555647
# Florida     12364569
# Illinois    12882135

# %%
#create a datafram for this in the below cell
city_networth = {
    'California':126789,
    'Texas':939393,
    'New York':348030340,
    'Florida':4384320,
    'Illinois':98540340
}

# %%
df.shape # DataFrame shape will give you the information similar to 2D numpy array with rows and columns
# Out:
# (5, 1)

# %%
df = pd.DataFrame(population, columns=['Population'])  # changing the name of the column while creating the DataFrame
df
# Out:
#             Population
# California    38956785
# Texas         26441568
# New York      19555647
# Florida       12364569
# Illinois      12882135

# %%
# Creating the pandas DataFrame with list of the dictionries
data = [ {'a':i, 'b':2*i} for i in range(3) ]
data
# Out:
# [{'a': 0, 'b': 0}, {'a': 1, 'b': 2}, {'a': 2, 'b': 4}]

# %%
df = pd.DataFrame(data)
df
# Out:
#    a  b
# 0  0  0
# 1  1  2
# 2  2  4

# %%
# a customized index can be setup for a smaller DataFrame
df = pd.DataFrame(data, index=['X','Y','Z'])
df
# Out:
#    a  b
# X  0  0
# Y  1  2
# Z  2  4

# %%
# to check the name of the columns use df.columns
df.columns
# Out:
# Index(['a', 'b'], dtype='object')

# %%
# to change the names of the columns use 'df.columns=list of the new column names'
df.columns=['A','B']
df
# Out:
#    A  B
# X  0  0
# Y  1  2
# Z  2  4

# %%
# to change the index of the DataFrame use after creating the DataFrame use 'df.index=list of the new index values'
df.index=['i','ii','iii']
df
# Out:
#      A  B
# i    0  0
# ii   1  2
# iii  2  4

# %%
df.columns=['column1','column2']
df
# Out:
#      column1  column2
# i          0        0
# ii         1        2
# iii        2        4

# %%
print(df.columns)
# Out:
# Index(['column1', 'column2'], dtype='object')

# %%
print(df.columns[0])  # to get name of the column according to index position use df.column[index of the column]
# Out:
# column1

# %%
print(df.columns[1])
# Out:
# column2

# %%
print(list(df.columns))
# Out:
# ['column1', 'column2']

# %%
df.index
# Out:
# Index(['i', 'ii', 'iii'], dtype='object')

# %%
print(list(df.index))
# Out:
# ['i', 'ii', 'iii']

# %%
df
# Out:
#      column1  column2
# i          0        0
# ii         1        2
# iii        2        4

# %%
# if a DataFrame is created using the dictionary and the keys are not matched in two dictionaries then it will be filled with NaN values

pd.DataFrame([{'a':1, 'b':2}, {'b':3, 'c': 4}])
# Out:
#      a  b    c
# 0  1.0  2  NaN
# 1  NaN  3  4.0

# %%
# Creat dataframe from numpy array
import numpy as np
pd.DataFrame(np.random.rand(3, 2), columns = ['Class1', 'Class2'], index = ['a', 'b', 'c'])
# Out:
#      Class1    Class2
# a  0.160534  0.862059
# b  0.086445  0.548736
# c  0.487440  0.465451

# %%
d = [{'city' : 'Delhi', 'data' : 1000}, {'city' : 'Mumbai', 'data' : 2000},
     {'city' : 'Banglore', 'data' : 1500}]
d
# Out:
# [{'city': 'Delhi', 'data': 1000},
#  {'city': 'Mumbai', 'data': 2000},
#  {'city': 'Banglore', 'data': 1500}]

# %%
pd.DataFrame(d)
# Out:
#        city  data
# 0     Delhi  1000
# 1    Mumbai  2000
# 2  Banglore  1500

# %% [markdown]
# #Importing Data to creat DataFrame

# %%
# csv files
import pandas as pd
path='https://raw.githubusercontent.com/ubaid-shah/datasets/main/student_records.csv'
df = pd.read_csv('https://raw.githubusercontent.com/ubaid-shah/datasets/main/student_records.csv')
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90          85.0       Yes
# 1    John            C        N             85          51.0       Yes
# 2   David            F        N             10          17.0        No
# 3  Holmes            B        Y             75          71.0        No
# 4  Marvin            E        N             20          30.0        No
# 5   Simon            A        Y             92          79.0       Yes
# 6  Robert            B        Y             60          59.0        No
# 7   Trent            C        Y             75          33.0        No
# 8    Judy          NaN        Y             25           NaN        No
# 9   Chris            D        U             25          15.0        NO

# %% [markdown]
# #Data Exploration

# %% [markdown]
# ata exploration will help finding the information about the data. In pandas it can be done using diiferent ways.
#
# Viewing/Inspecting Data Use these commands to take a look at specific sections of your pandas DataFrame or Series.
#
# df.head(n) | First n rows of the DataFrame
#
# By default, it returns the first 5 rows of the Dataframe.
#
# df.tail(n)| Last n rows of the DataFrame
#
# By default, it returns the last 5 rows of the Dataframe.
#
# df.shape| Number of rows and columns
#
# df.size | Number of elements in this object.
#
# Return the number of rows if Series, otherwise returns the number of rows times the number of columns if DataFrame.
#
# df.info()| Index, Datatype and Memory information
#
# df.describe()| Summary statistics for numerical columns
#
# df.value_counts(dropna=False) | View unique values and counts
#
# df.apply(pd.Series.value_counts) | Unique values and counts for all columns
#
# df.ndim| Returns dimension of dataframe/series.
#
# 1 for one dimension (series), 2 for two dimensions (dataframe).
#
# df.sample( ) | generate a sample randomly either row or column.
#
# It allows you to select values randomly from a Series or DataFrame. It is useful when we want to select a random sample from a distribution.
#
# df.isna( ) or df.isnull() | This function returns a dataframe filled with boolean values with true indicating missing values.
#
# df.isnull( ).sum( ) | Return the number of missing values in each column.
#
# df.dropna( ) | remove a row or a column from a dataframe that has a NaN or missing values in it.

# %% [markdown]
# #Basic Data Exploration

# %%
df.head()
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90          85.0       Yes
# 1    John            C        N             85          51.0       Yes
# 2   David            F        N             10          17.0        No
# 3  Holmes            B        Y             75          71.0        No
# 4  Marvin            E        N             20          30.0        No

# %%
df.tail()
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 5   Simon            A        Y             92          79.0       Yes
# 6  Robert            B        Y             60          59.0        No
# 7   Trent            C        Y             75          33.0        No
# 8    Judy          NaN        Y             25           NaN        No
# 9   Chris            D        U             25          15.0        NO

# %%
df.head(3)
# Out:
#     Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0  Henry            A        Y             90          85.0       Yes
# 1   John            C        N             85          51.0       Yes
# 2  David            F        N             10          17.0        No

# %%
df.head(1)
# Out:
#     Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0  Henry            A        Y             90          85.0       Yes

# %%
df.tail(2)
# Out:
#     Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 8   Judy          NaN        Y             25           NaN        No
# 9  Chris            D        U             25          15.0        NO

# %%
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90          85.0       Yes
# 1    John            C        N             85          51.0       Yes
# 2   David            F        N             10          17.0        No
# 3  Holmes            B        Y             75          71.0        No
# 4  Marvin            E        N             20          30.0        No
# 5   Simon            A        Y             92          79.0       Yes
# 6  Robert            B        Y             60          59.0        No
# 7   Trent            C        Y             75          33.0        No
# 8    Judy          NaN        Y             25           NaN        No
# 9   Chris            D        U             25          15.0        NO

# %%
ser = df.ProjectScore # creat a series from one column from the dataset
print(ser)
print(type(ser))
print(ser.shape)
# Out:
# 0    85.0
# 1    51.0
# 2    17.0
# 3    71.0
# 4    30.0
# 5    79.0
# 6    59.0
# 7    33.0
# 8     NaN
# 9    15.0
# Name: ProjectScore, dtype: float64
# <class 'pandas.core.series.Series'>
# (10,)

# %%
df.shape
# Out:
# (10, 6)

# %%
df.size
# Out:
# 60

# %%
df.ndim
# Out:
# 2

# %%
df.sample() # generate a random sample
# Out:
#    Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 8  Judy          NaN        Y             25           NaN        No

# %%
df.sample(3)
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 6  Robert            B        Y             60          59.0        No
# 3  Holmes            B        Y             75          71.0        No
# 5   Simon            A        Y             92          79.0       Yes

# %%
df.columns
# Out:
# Index(['Name', 'OverallGrade', 'Obedient', 'ResearchScore', 'ProjectScore',
#        'Recommend'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['Name',
#  'OverallGrade',
#  'Obedient',
#  'ResearchScore',
#  'ProjectScore',
#  'Recommend']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           10 non-null     object
#  1   OverallGrade   9 non-null      object
#  2   Obedient       10 non-null     object
#  3   ResearchScore  10 non-null     int64
#  4   ProjectScore   9 non-null      float64
#  5   Recommend      10 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 612.0+ bytes

# %%
df.dtypes
# Out:
# Name              object
# OverallGrade      object
# Obedient          object
# ResearchScore      int64
# ProjectScore     float64
# Recommend         object
# dtype: object

# %% [markdown]
# #Statistics Summary

# %%
df.describe()
# Out:
#        ResearchScore  ProjectScore
# count      10.000000      9.000000
# mean       55.700000     48.888889
# std        32.256093     26.412329
# min        10.000000     15.000000
# 25%        25.000000     30.000000
# 50%        67.500000     51.000000
# 75%        82.500000     71.000000
# max        92.000000     85.000000

# %%
df.describe().T
# Out:
#                count       mean        std   min   25%   50%   75%   max
# ResearchScore   10.0  55.700000  32.256093  10.0  25.0  67.5  82.5  92.0
# ProjectScore     9.0  48.888889  26.412329  15.0  30.0  51.0  71.0  85.0

# %%
df['ResearchScore'].describe()
# Out:
# count    10.000000
# mean     55.700000
# std      32.256093
# min      10.000000
# 25%      25.000000
# 50%      67.500000
# 75%      82.500000
# max      92.000000
# Name: ResearchScore, dtype: float64

# %%
round(df[['ResearchScore', 'ProjectScore']].describe(), 2)
# Out:
#        ResearchScore  ProjectScore
# count          10.00          9.00
# mean           55.70         48.89
# std            32.26         26.41
# min            10.00         15.00
# 25%            25.00         30.00
# 50%            67.50         51.00
# 75%            82.50         71.00
# max            92.00         85.00

# %%
round(df.describe(), 2)
# Out:
#        ResearchScore  ProjectScore
# count          10.00          9.00
# mean           55.70         48.89
# std            32.26         26.41
# min            10.00         15.00
# 25%            25.00         30.00
# 50%            67.50         51.00
# 75%            82.50         71.00
# max            92.00         85.00

# %%
df['ResearchScore'].mean()
# Out:
# 55.7

# %%
df['ResearchScore'].count()
# Out:
# 10

# %%
# to get the names of the Numeric columns
df.describe().columns
# Out:
# Index(['ResearchScore', 'ProjectScore'], dtype='object')

# %%
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90          85.0       Yes
# 1    John            C        N             85          51.0       Yes
# 2   David            F        N             10          17.0        No
# 3  Holmes            B        Y             75          71.0        No
# 4  Marvin            E        N             20          30.0        No
# 5   Simon            A        Y             92          79.0       Yes
# 6  Robert            B        Y             60          59.0        No
# 7   Trent            C        Y             75          33.0        No
# 8    Judy          NaN        Y             25           NaN        No
# 9   Chris            D        U             25          15.0        NO

# %%
# df.drop(coulumns,axis=1) will delete the columns from the DataFrame
x = df.drop('Name',axis=1)
x
# Out:
#   OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0            A        Y             90          85.0       Yes
# 1            C        N             85          51.0       Yes
# 2            F        N             10          17.0        No
# 3            B        Y             75          71.0        No
# 4            E        N             20          30.0        No
# 5            A        Y             92          79.0       Yes
# 6            B        Y             60          59.0        No
# 7            C        Y             75          33.0        No
# 8          NaN        Y             25           NaN        No
# 9            D        U             25          15.0        NO

# %%
set(x.columns)       # to create the set of the columns
# Out:
# {'Obedient', 'OverallGrade', 'ProjectScore', 'Recommend', 'ResearchScore'}

# %%
set(x.describe().columns)
# Out:
# {'ProjectScore', 'ResearchScore'}

# %%
set(x.columns) - set(x.describe().columns)
# Out:
# {'Obedient', 'OverallGrade', 'Recommend'}

# %%
cat_col = list(set(x.columns) - set(x.describe().columns))

# %%
x[cat_col]
# Out:
#   Recommend OverallGrade Obedient
# 0       Yes            A        Y
# 1       Yes            C        N
# 2        No            F        N
# 3        No            B        Y
# 4        No            E        N
# 5       Yes            A        Y
# 6        No            B        Y
# 7        No            C        Y
# 8        No          NaN        Y
# 9        NO            D        U

# %%
df[cat_col].describe()
# Out:
#        Recommend OverallGrade Obedient
# count         10            9       10
# unique         3            6        3
# top           No            A        Y
# freq           6            2        6

# %%
x.describe(include = 'object')
# Out:
#        OverallGrade Obedient Recommend
# count             9       10        10
# unique            6        3         3
# top               A        Y        No
# freq              2        6         6

# %%
x.describe(include = 'all')
# Out:
#        OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# count             9       10      10.000000      9.000000        10
# unique            6        3            NaN           NaN         3
# top               A        Y            NaN           NaN        No
# freq              2        6            NaN           NaN         6
# mean            NaN      NaN      55.700000     48.888889       NaN
# std             NaN      NaN      32.256093     26.412329       NaN
# min             NaN      NaN      10.000000     15.000000       NaN
# 25%             NaN      NaN      25.000000     30.000000       NaN
# 50%             NaN      NaN      67.500000     51.000000       NaN
# 75%             NaN      NaN      82.500000     71.000000       NaN
# max             NaN      NaN      92.000000     85.000000       NaN

# %% [markdown]
# #Value counts

# %%
df['Recommend'].value_counts()
# Out:
# Recommend
# No     6
# Yes    3
# NO     1
# Name: count, dtype: int64

# %%
df['Recommend'].value_counts(normalize = True)
# Out:
# Recommend
# No     0.6
# Yes    0.3
# NO     0.1
# Name: proportion, dtype: float64

# %%
df['Recommend'].value_counts(normalize = True) * 100
# Out:
# Recommend
# No     60.0
# Yes    30.0
# NO     10.0
# Name: proportion, dtype: float64

# %%
df['OverallGrade'].value_counts()
# Out:
# OverallGrade
# A    2
# C    2
# B    2
# F    1
# E    1
# D    1
# Name: count, dtype: int64

# %%
#The above value_counts will not include the NaN values. To consider the NaN values use .value_counts(dropna=False)

# %%
df['OverallGrade'].value_counts(dropna=False)
# Out:
# OverallGrade
# A      2
# C      2
# B      2
# F      1
# E      1
# NaN    1
# D      1
# Name: count, dtype: int64

# %%
df['OverallGrade'].value_counts(dropna=False, normalize = True)
# Out:
# OverallGrade
# A      0.2
# C      0.2
# B      0.2
# F      0.1
# E      0.1
# NaN    0.1
# D      0.1
# Name: proportion, dtype: float64

# %%
df['OverallGrade'].value_counts(dropna=False, normalize = True) * 100
# Out:
# OverallGrade
# A      20.0
# C      20.0
# B      20.0
# F      10.0
# E      10.0
# NaN    10.0
# D      10.0
# Name: proportion, dtype: float64

# %%
df.apply(pd.Series.value_counts) # Unique values and counts for all columns
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-0a6fc02770e5> in <cell line: 0>()
# ----> 1 df.apply(pd.Series.value_counts) # Unique values and counts for all columns
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10372             kwargs=kwargs,
#   10373         )
# > 10374         return op.apply().__finalize__(self, method="apply")
#   10375
#   10376     def map(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply(self)
#     914             return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
#     915
# --> 916         return self.apply_standard()
#     917
#     918     def agg(self):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1066
#    1067         # wrap results
# -> 1068         return self.wrap_results(results, res_index)
#    1069
#    1070     def apply_series_generator(self) -> tuple[ResType, Index]:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in wrap_results(self, results, res_index)
#    1105         # see if we can infer the results
#    1106         if len(results) > 0 and 0 in results and is_sequence(results[0]):
# -> 1107             return self.wrap_results_for_axis(results, res_index)
#    1108
#    1109         # dict of scalars
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in wrap_results_for_axis(self, results, res_index)
#    1217
#    1218         try:
# -> 1219             result = self.obj._constructor(data=results)
#    1220         except ValueError as err:
#    1221             if "All arrays must be of the same length" in str(err):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     776         elif isinstance(data, dict):
#     777             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779         elif isinstance(data, ma.MaskedArray):
#     780             from numpy.ma import mrecords
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     501             arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
#     502
# --> 503     return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#     504
#     505
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     112         # figure out the index, if necessary
#     113         if index is None:
# --> 114             index = _extract_index(arrays)
#     115         else:
#     116             index = ensure_index(index)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/construction.py in _extract_index(data)
#     668
#     669     if have_series:
# --> 670         index = union_indexes(indexes)
#     671     elif have_dicts:
#     672         index = union_indexes(indexes, sort=False)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/api.py in union_indexes(indexes, sort)
#     317         index = indexes[0]
#     318         if not all(index.equals(other) for other in indexes[1:]):
# --> 319             index = _unique_indices(indexes, dtype)
#     320
#     321         name = get_unanimous_names(*indexes)[0]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/api.py in _unique_indices(inds, dtype)
#     250                 result = result.append(diff.unique())
#     251             if sort:
# --> 252                 result = result.sort_values()
#     253             return result
#     254
#
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in sort_values(self, return_indexer, ascending, na_position, key)
#    5930         # ignore na_position for MultiIndex
#    5931         if not isinstance(self, ABCMultiIndex):
# -> 5932             _as = nargsort(
#    5933                 items=self, ascending=ascending, na_position=na_position, key=key
#    5934             )
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/sorting.py in nargsort(items, kind, ascending, na_position, key, mask)
#     437         non_nans = non_nans[::-1]
#     438         non_nan_idx = non_nan_idx[::-1]
# --> 439     indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     440     if not ascending:
#     441         indexer = indexer[::-1]
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %% [markdown]
# #Dealing with Null Values

# %% [markdown]
# Checking the null values in the DataFrame

# %%
df.isna()
# Out:
#     Name  OverallGrade  Obedient  ResearchScore  ProjectScore  Recommend
# 0  False         False     False          False         False      False
# 1  False         False     False          False         False      False
# 2  False         False     False          False         False      False
# 3  False         False     False          False         False      False
# 4  False         False     False          False         False      False
# 5  False         False     False          False         False      False
# 6  False         False     False          False         False      False
# 7  False         False     False          False         False      False
# 8  False          True     False          False          True      False
# 9  False         False     False          False         False      False

# %%
df.isnull()
# Out:
#     Name  OverallGrade  Obedient  ResearchScore  ProjectScore  Recommend
# 0  False         False     False          False         False      False
# 1  False         False     False          False         False      False
# 2  False         False     False          False         False      False
# 3  False         False     False          False         False      False
# 4  False         False     False          False         False      False
# 5  False         False     False          False         False      False
# 6  False         False     False          False         False      False
# 7  False         False     False          False         False      False
# 8  False          True     False          False          True      False
# 9  False         False     False          False         False      False

# %%
df.isnull().sum()
# Out:
# Name             0
# OverallGrade     1
# Obedient         0
# ResearchScore    0
# ProjectScore     1
# Recommend        0
# dtype: int64

# %%
df.shape[0]
# Out:
# 10

# %%
df.isnull().sum() * 100/df.shape[0] #return the number of missing values in each column in percentage
# Out:
# Name              0.0
# OverallGrade     10.0
# Obedient          0.0
# ResearchScore     0.0
# ProjectScore     10.0
# Recommend         0.0
# dtype: float64

# %% [markdown]
# Handeling The Null Values In order to deal with NaN or Null values there are multiple ways according to the projects or data as follows.
#
# Drop all null values Fill Null values

# %%
x = df.dropna()
x
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90          85.0       Yes
# 1    John            C        N             85          51.0       Yes
# 2   David            F        N             10          17.0        No
# 3  Holmes            B        Y             75          71.0        No
# 4  Marvin            E        N             20          30.0        No
# 5   Simon            A        Y             92          79.0       Yes
# 6  Robert            B        Y             60          59.0        No
# 7   Trent            C        Y             75          33.0        No
# 9   Chris            D        U             25          15.0        NO

# %%
x = df.dropna(axis = 1)
x
# Out:
#      Name Obedient  ResearchScore Recommend
# 0   Henry        Y             90       Yes
# 1    John        N             85       Yes
# 2   David        N             10        No
# 3  Holmes        Y             75        No
# 4  Marvin        N             20        No
# 5   Simon        Y             92       Yes
# 6  Robert        Y             60        No
# 7   Trent        Y             75        No
# 8    Judy        Y             25        No
# 9   Chris        U             25        NO

# %%
x = df.dropna(how='any')
x
# ‘any’ : If any NA values are present, drop that row or column.
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90          85.0       Yes
# 1    John            C        N             85          51.0       Yes
# 2   David            F        N             10          17.0        No
# 3  Holmes            B        Y             75          71.0        No
# 4  Marvin            E        N             20          30.0        No
# 5   Simon            A        Y             92          79.0       Yes
# 6  Robert            B        Y             60          59.0        No
# 7   Trent            C        Y             75          33.0        No
# 9   Chris            D        U             25          15.0        NO

# %%
x = df.dropna(how = 'all')
x
#if all values are NA, drop that row or column
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90          85.0       Yes
# 1    John            C        N             85          51.0       Yes
# 2   David            F        N             10          17.0        No
# 3  Holmes            B        Y             75          71.0        No
# 4  Marvin            E        N             20          30.0        No
# 5   Simon            A        Y             92          79.0       Yes
# 6  Robert            B        Y             60          59.0        No
# 7   Trent            C        Y             75          33.0        No
# 8    Judy          NaN        Y             25           NaN        No
# 9   Chris            D        U             25          15.0        NO

# %%
x.dropna(inplace = True) # Whether to modify the DataFrame rather than creating a new one
x
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90          85.0       Yes
# 1    John            C        N             85          51.0       Yes
# 2   David            F        N             10          17.0        No
# 3  Holmes            B        Y             75          71.0        No
# 4  Marvin            E        N             20          30.0        No
# 5   Simon            A        Y             92          79.0       Yes
# 6  Robert            B        Y             60          59.0        No
# 7   Trent            C        Y             75          33.0        No
# 9   Chris            D        U             25          15.0        NO

# %% [markdown]
# #Fill Null Values:
# 1. .fillna()
# 2. .interpolate()

# %%
x = df.fillna(0)
x
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90          85.0       Yes
# 1    John            C        N             85          51.0       Yes
# 2   David            F        N             10          17.0        No
# 3  Holmes            B        Y             75          71.0        No
# 4  Marvin            E        N             20          30.0        No
# 5   Simon            A        Y             92          79.0       Yes
# 6  Robert            B        Y             60          59.0        No
# 7   Trent            C        Y             75          33.0        No
# 8    Judy            0        Y             25           0.0        No
# 9   Chris            D        U             25          15.0        NO

# %%
x['OverallGrade'].mode()
# Out:
# 0    A
# 1    B
# 2    C
# Name: OverallGrade, dtype: object

# %%
x.fillna(method = 'bfill')
# Out:
# <ipython-input-121-d5d19a07de53>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   x.fillna(method = 'bfill')
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90          85.0       Yes
# 1    John            C        N             85          51.0       Yes
# 2   David            F        N             10          17.0        No
# 3  Holmes            B        Y             75          71.0        No
# 4  Marvin            E        N             20          30.0        No
# 5   Simon            A        Y             92          79.0       Yes
# 6  Robert            B        Y             60          59.0        No
# 7   Trent            C        Y             75          33.0        No
# 8    Judy            0        Y             25           0.0        No
# 9   Chris            D        U             25          15.0        NO

# %%
x.fillna(method = 'bfill', axis = 1)
# Out:
# <ipython-input-122-c85aff0f86bc>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   x.fillna(method = 'bfill', axis = 1)
#      Name OverallGrade Obedient ResearchScore ProjectScore Recommend
# 0   Henry            A        Y            90         85.0       Yes
# 1    John            C        N            85         51.0       Yes
# 2   David            F        N            10         17.0        No
# 3  Holmes            B        Y            75         71.0        No
# 4  Marvin            E        N            20         30.0        No
# 5   Simon            A        Y            92         79.0       Yes
# 6  Robert            B        Y            60         59.0        No
# 7   Trent            C        Y            75         33.0        No
# 8    Judy            0        Y            25          0.0        No
# 9   Chris            D        U            25         15.0        NO

# %%
x.fillna(method = 'ffill')
# Out:
# <ipython-input-123-7bb456a728d0>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   x.fillna(method = 'ffill')
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90          85.0       Yes
# 1    John            C        N             85          51.0       Yes
# 2   David            F        N             10          17.0        No
# 3  Holmes            B        Y             75          71.0        No
# 4  Marvin            E        N             20          30.0        No
# 5   Simon            A        Y             92          79.0       Yes
# 6  Robert            B        Y             60          59.0        No
# 7   Trent            C        Y             75          33.0        No
# 8    Judy            0        Y             25           0.0        No
# 9   Chris            D        U             25          15.0        NO

# %%
x.fillna(method = 'ffill', axis = 1)
# Out:
# <ipython-input-124-2ea3fdbda59b>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   x.fillna(method = 'ffill', axis = 1)
#      Name OverallGrade Obedient ResearchScore ProjectScore Recommend
# 0   Henry            A        Y            90         85.0       Yes
# 1    John            C        N            85         51.0       Yes
# 2   David            F        N            10         17.0        No
# 3  Holmes            B        Y            75         71.0        No
# 4  Marvin            E        N            20         30.0        No
# 5   Simon            A        Y            92         79.0       Yes
# 6  Robert            B        Y            60         59.0        No
# 7   Trent            C        Y            75         33.0        No
# 8    Judy            0        Y            25          0.0        No
# 9   Chris            D        U            25         15.0        NO

# %%
df['Recommend'].unique()
# Out:
# array(['Yes', 'No', 'NO'], dtype=object)

# %%
df['OverallGrade'].unique()
# Out:
# array(['A', 'C', 'F', 'B', 'E', nan, 'D'], dtype=object)

# %%
df['Recommend'] = df['Recommend'].replace('NO', 'No')

# %%
df['Recommend'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['ResearchScore'].sum()
# Out:
# 557

# %%
col_num = df.describe().columns
x = df[col_num]
x
# Out:
#    ResearchScore  ProjectScore
# 0             90          85.0
# 1             85          51.0
# 2             10          17.0
# 3             75          71.0
# 4             20          30.0
# 5             92          79.0
# 6             60          59.0
# 7             75          33.0
# 8             25           NaN
# 9             25          15.0

# %%
x.sum()
# Out:
# ResearchScore    557.0
# ProjectScore     440.0
# dtype: float64

# %%
x.sum(axis = 0)
# Out:
# ResearchScore    557.0
# ProjectScore     440.0
# dtype: float64

# %%
x.sum(axis = 1)
# Out:
# 0    175.0
# 1    136.0
# 2     27.0
# 3    146.0
# 4     50.0
# 5    171.0
# 6    119.0
# 7    108.0
# 8     25.0
# 9     40.0
# dtype: float64

# %%
x.mean(axis=0)
# Out:
# ResearchScore    55.700000
# ProjectScore     48.888889
# dtype: float64

# %%
x.mean(axis=1)
# Out:
# 0    87.5
# 1    68.0
# 2    13.5
# 3    73.0
# 4    25.0
# 5    85.5
# 6    59.5
# 7    54.0
# 8    25.0
# 9    20.0
# dtype: float64

# %%
x.count(axis=0)
# Out:
# ResearchScore    10
# ProjectScore      9
# dtype: int64

# %%
x.count(axis=1)
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# 5    2
# 6    2
# 7    2
# 8    1
# 9    2
# dtype: int64

# %%
x.min(axis=0)
# Out:
# ResearchScore    10.0
# ProjectScore     15.0
# dtype: float64

# %%
x.min(axis=1)
# Out:
# 0    85.0
# 1    51.0
# 2    10.0
# 3    71.0
# 4    20.0
# 5    79.0
# 6    59.0
# 7    33.0
# 8    25.0
# 9    15.0
# dtype: float64

# %%
x.max(axis=0)
# Out:
# ResearchScore    92.0
# ProjectScore     85.0
# dtype: float64

# %%
x.max(axis=1)
# Out:
# 0    90.0
# 1    85.0
# 2    17.0
# 3    75.0
# 4    30.0
# 5    92.0
# 6    60.0
# 7    75.0
# 8    25.0
# 9    25.0
# dtype: float64

# %%
x.median(axis=0)
# Out:
# ResearchScore    67.5
# ProjectScore     51.0
# dtype: float64

# %%
x.median(axis=1)
# Out:
# 0    87.5
# 1    68.0
# 2    13.5
# 3    73.0
# 4    25.0
# 5    85.5
# 6    59.5
# 7    54.0
# 8    25.0
# 9    20.0
# dtype: float64

# %%
x.mode(axis=0)
# Out:
#    ResearchScore  ProjectScore
# 0           25.0          15.0
# 1           75.0          17.0
# 2            NaN          30.0
# 3            NaN          33.0
# 4            NaN          51.0
# 5            NaN          59.0
# 6            NaN          71.0
# 7            NaN          79.0
# 8            NaN          85.0

# %%
x.mode(axis=1)
# Out:
#       0     1
# 0  85.0  90.0
# 1  51.0  85.0
# 2  10.0  17.0
# 3  71.0  75.0
# 4  20.0  30.0
# 5  79.0  92.0
# 6  59.0  60.0
# 7  33.0  75.0
# 8  25.0   NaN
# 9  15.0  25.0

# %%
x.std(axis=0)
# Out:
# ResearchScore    32.256093
# ProjectScore     26.412329
# dtype: float64

# %%
x.std(axis=1)
# Out:
# 0     3.535534
# 1    24.041631
# 2     4.949747
# 3     2.828427
# 4     7.071068
# 5     9.192388
# 6     0.707107
# 7    29.698485
# 8          NaN
# 9     7.071068
# dtype: float64

# %%
x.var(axis=0)
# Out:
# ResearchScore    1040.455556
# ProjectScore      697.611111
# dtype: float64

# %%
x.var(axis=1)
# Out:
# 0     12.5
# 1    578.0
# 2     24.5
# 3      8.0
# 4     50.0
# 5     84.5
# 6      0.5
# 7    882.0
# 8      NaN
# 9     50.0
# dtype: float64

# %%
x.cov()
# Out:
#                ResearchScore  ProjectScore
# ResearchScore    1040.455556    716.138889
# ProjectScore      716.138889    697.611111

# %%
x.corr()
# Out:
#                ResearchScore  ProjectScore
# ResearchScore       1.000000      0.840921
# ProjectScore        0.840921      1.000000

# %%
# Pandas dataframe.cumsum() is used to find the cumulative sum value over any axis.
# Each cell is populated with the cumulative sum of the values seen so far.

# %%
print(x)
# Out:
#    ResearchScore  ProjectScore
# 0             90          85.0
# 1             85          51.0
# 2             10          17.0
# 3             75          71.0
# 4             20          30.0
# 5             92          79.0
# 6             60          59.0
# 7             75          33.0
# 8             25           NaN
# 9             25          15.0

# %%
print()

# %%
print(x.cumsum())
# Out:
#    ResearchScore  ProjectScore
# 0             90          85.0
# 1            175         136.0
# 2            185         153.0
# 3            260         224.0
# 4            280         254.0
# 5            372         333.0
# 6            432         392.0
# 7            507         425.0
# 8            532           NaN
# 9            557         440.0

# %%
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90          85.0       Yes
# 1    John            C        N             85          51.0       Yes
# 2   David            F        N             10          17.0        No
# 3  Holmes            B        Y             75          71.0        No
# 4  Marvin            E        N             20          30.0        No
# 5   Simon            A        Y             92          79.0       Yes
# 6  Robert            B        Y             60          59.0        No
# 7   Trent            C        Y             75          33.0        No
# 8    Judy          NaN        Y             25           NaN        No
# 9   Chris            D        U             25          15.0        No

# %%
df = df.sort_values(by='ResearchScore')

# %%
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 2   David            F        N             10          17.0        No
# 4  Marvin            E        N             20          30.0        No
# 8    Judy          NaN        Y             25           NaN        No
# 9   Chris            D        U             25          15.0        No
# 6  Robert            B        Y             60          59.0        No
# 3  Holmes            B        Y             75          71.0        No
# 7   Trent            C        Y             75          33.0        No
# 1    John            C        N             85          51.0       Yes
# 0   Henry            A        Y             90          85.0       Yes
# 5   Simon            A        Y             92          79.0       Yes

# %%
df = df.sort_values(by='ResearchScore', ascending=False)

# %%
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 5   Simon            A        Y             92          79.0       Yes
# 0   Henry            A        Y             90          85.0       Yes
# 1    John            C        N             85          51.0       Yes
# 3  Holmes            B        Y             75          71.0        No
# 7   Trent            C        Y             75          33.0        No
# 6  Robert            B        Y             60          59.0        No
# 8    Judy          NaN        Y             25           NaN        No
# 9   Chris            D        U             25          15.0        No
# 4  Marvin            E        N             20          30.0        No
# 2   David            F        N             10          17.0        No

# %%
df=df.sort_values(by=['OverallGrade', 'ResearchScore'], ascending = False)

# %%
df
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 2   David            F        N             10          17.0        No
# 4  Marvin            E        N             20          30.0        No
# 9   Chris            D        U             25          15.0        No
# 1    John            C        N             85          51.0       Yes
# 7   Trent            C        Y             75          33.0        No
# 3  Holmes            B        Y             75          71.0        No
# 6  Robert            B        Y             60          59.0        No
# 5   Simon            A        Y             92          79.0       Yes
# 0   Henry            A        Y             90          85.0       Yes
# 8    Judy          NaN        Y             25           NaN        No

# %%
x.reset_index(inplace=True)

# %%
x
# Out:
#    index  ResearchScore  ProjectScore
# 0      0             90          85.0
# 1      1             85          51.0
# 2      2             10          17.0
# 3      3             75          71.0
# 4      4             20          30.0
# 5      5             92          79.0
# 6      6             60          59.0
# 7      7             75          33.0
# 8      8             25           NaN
# 9      9             25          15.0

# %%
x.drop(columns=['index'], inplace = True)
x
# Out:
# <ipython-input-167-924d7b797f07>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.drop(columns=['index'], inplace = True)
#    ResearchScore  ProjectScore
# 0             90          85.0
# 1             85          51.0
# 2             10          17.0
# 3             75          71.0
# 4             20          30.0
# 5             92          79.0
# 6             60          59.0
# 7             75          33.0
# 8             25           NaN
# 9             25          15.0

# %%
x=df.sort_values(by=['ResearchScore', 'ProjectScore'])

# %%
x
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 2   David            F        N             10          17.0        No
# 4  Marvin            E        N             20          30.0        No
# 9   Chris            D        U             25          15.0        No
# 8    Judy          NaN        Y             25           NaN        No
# 6  Robert            B        Y             60          59.0        No
# 7   Trent            C        Y             75          33.0        No
# 3  Holmes            B        Y             75          71.0        No
# 1    John            C        N             85          51.0       Yes
# 0   Henry            A        Y             90          85.0       Yes
# 5   Simon            A        Y             92          79.0       Yes

# %%
x.sort_index()
# Out:
#      Name OverallGrade Obedient  ResearchScore  ProjectScore Recommend
# 0   Henry            A        Y             90          85.0       Yes
# 1    John            C        N             85          51.0       Yes
# 2   David            F        N             10          17.0        No
# 3  Holmes            B        Y             75          71.0        No
# 4  Marvin            E        N             20          30.0        No
# 5   Simon            A        Y             92          79.0       Yes
# 6  Robert            B        Y             60          59.0        No
# 7   Trent            C        Y             75          33.0        No
# 8    Judy          NaN        Y             25           NaN        No
# 9   Chris            D        U             25          15.0        No

# %% [markdown]
# #Drop duplicates

# %%
df = pd.DataFrame({
    'brand': ['Yum Yum', 'Yum Yum', 'Indomie', 'Indomie', 'Indomie'],
    'style': ['cup', 'cup', 'cup', 'pack', 'pack'],
    'rating': [4, 4, 3.5, 15, 5]
    })
df
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
df.drop_duplicates()
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
df.drop_duplicates(subset=['brand'])
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5

# %%
df.drop_duplicates(subset=['brand', 'style'], keep='last')
# Out:
#      brand style  rating
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 4  Indomie  pack     5.0
